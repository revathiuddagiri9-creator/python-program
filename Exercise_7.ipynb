# %% [markdown]
# <a href="https://colab.research.google.com/github/revathiuddagiri9-creator/python-program/blob/main/Exercise_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#operations in tuples
t=()
t1=(1,2,3)
t2=(1,2,3,4.5)
t3=t1+t2  #concatenation
for i in t1: #iteration
  print(i)
print(t1[1:3]) #slicing
print(10 in t2)  #membership
print(t1*2)  #repetation
print(t1)
print(t2)
print(t3)
# Out:
# 1
# 2
# 3
# (2, 3)
# False
# (1, 2, 3, 1, 2, 3)
# (1, 2, 3)
# (1, 2, 3, 4.5)
# (1, 2, 3, 1, 2, 3, 4.5)

# %%
t1=(1,2,3)
print(max(t1))
print(max(t1))
print(min(t1))
# Out:
# 3
# 3
# 1

# %%
#methods
numbers=(10,20,30,10,40,50,10)
print(numbers.count(10))
print(numbers.index(30))
# Out:
# 3
# 2

# %%
#zip
t4=(4,6,8)
print(tuple(zip(t1,t4)))
# Out:
# ((1, 4), (2, 6), (3, 8))

# %%
#user defined
t=tuple(map(int,input("enter values").split()))
print(t)
T=tuple(int(x) for x in input().split())
# Out:
# enter values6 2 8 0
# (6, 2, 8, 0)
# 4 7 1 87

# %%
#list in tuple
#tuple in list
t=(10,20,30,[40,50,60])
print(t)
print(t[2])
print(t[3])
print(t[3][1])
t1=[1,2,3,(4,5,6)]
print(t1)
# Out:
# (10, 20, 30, [40, 50, 60])
# 30
# [40, 50, 60]
# 50
# [1, 2, 3, (4, 5, 6)]

# %%
#write a program to count the number of vowels in a string(No control #flow allowed)
s1=str(input("Enter a string"))
s1=s1.lower()
vowels_count=s1.count("a")+s1.count("e")+ s1.count("i")+s1.count("o")+s1.count("u")
print("the no of vowels are",vowels_count)
# Out:
# Enter a stringrevathi
# the no of vowels are 3

# %%
#program to create tuples for(name,age,addres,collage) for at least two membersand concatinate tuples and print output.
student1=("john",25,"gdv","vit")
student2 =("abc",36,"bvrm","vit")
print(student1+student2)
# Out:
# ('john', 25, 'gdv', 'vit', 'abc', 36, 'bvrm', 'vit')
