# %% [markdown]
# <a href="https://colab.research.google.com/github/revathiuddagiri9-creator/python-program/blob/main/Exercise_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sets
s={1,2,3,"hello",1,2,3}
print(s)
a={}
print(type(a))
a=set()
print(type(a))
# Out:
# {1, 2, 3, 'hello'}
# <class 'dict'>
# <class 'set'>

# %%
#Mathematical operations on sets
