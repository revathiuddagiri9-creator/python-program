# %% [markdown]
# <a href="https://colab.research.google.com/github/revathiuddagiri9-creator/python-program/blob/main/Untitled1_Exercise_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Append
M1=[6,2,0,'list']
M2=[1,9,3,'python']
M1.append("8")
print(M1)
# Out:
# [6, 2, 0, 'list', '8']

# %%
#insert
M1.insert(2,1)
print(M1)
# Out:
# [6, 2, 1, 0, 'list', '8']

# %%
#pop
M1.pop(2)
print(M1)
# Out:
# [6, 2, 0, 'list', '8']

# %%
print(M1)
# Out:
# [6, 2, 0, 'list', '8']

# %%
#remove
M2.remove(3)
print(M2)
# Out:
# [1, 9, 'python']

# %%
#extend
M1.extend(M2)
print(M1)
# Out:
# [6, 2, 0, 'list', '8', 1, 9, 'python']

# %%
#join two lists
M3=M1+M2
print(M3)
# Out:
# [6, 2, 0, 'list', '8', 1, 9, 'python', 1, 9, 'python']

# %%
#copy lists
M2=M1.copy()
print(M2)
# Out:
# [6, 2, 0, 'list', '8', 1, 9, 'python']

# %%
M2[1:3]=['new','gen']
print(M2)
# Out:
# [6, 'new', 'gen', 'list', '8', 1, 9, 'python']

# %%
#sort
s1=[3,9,1,9,4,6]
s1.sort()
print(s1)
# Out:
# [1, 3, 4, 6, 9, 9]

# %%
#copy
s1.count(9)
# Out:
# 2

# %%
#index
s1.index(1)
# Out:
# 0

# %%
#operations in a list
s1=[1,22,30,18,90]
s2=[3,5,6,8,9]
print(s1+s2)
print(s1[0])
print(s1[2:5])
print(s2[0:2:5])
print(s2[::-2])
print(s1*2)
print(30 in s1)
for i in s2:
  print(i)
# Out:
# [1, 22, 30, 18, 90, 3, 5, 6, 8, 9]
# 1
# [30, 18, 90]
# [3]
# [9, 6, 3]
# [1, 22, 30, 18, 90, 1, 22, 30, 18, 90]
# True
# 3
# 5
# 6
# 8
# 9

# %%
#predefined functions in a list
L1=[2,5,8]
print(sum(L1))
print(max(L1))
print(min(L1))
print(len(L1))
# Out:
# 15
# 8
# 2
# 3
