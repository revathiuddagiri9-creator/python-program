# %% [markdown]
# <a href="https://colab.research.google.com/github/revathiuddagiri9-creator/python-program/blob/main/week1/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
a=2
print(a)
print("enter a")
# Out:
# 2
# enter a

# %%
s=2
print(type(s))
# Out:
# <class 'int'>

# %%
a=int(input())
# Out:
# 2

# %%
a
# Out:
# 2

# %%
h=float(input())
# Out:
# 2.5

# %%
h
# Out:
# 2.5

# %%
t=str(input("enter something"))
# Out:
# enter somethinghi

# %%
t
# Out:
# 'hi'

# %%
a=int(input())
b=int(input())
print(a,b)
# Out:
# 25
# 6
# 25 6

# %%
print(2+3)
# Out:
# 5

# %%
print(a+b)
# Out:
# 31

# %%
print(a-b)
# Out:
# 19

# %%
print(a//b)
# Out:
# 4

# %%
print(a/b)
# Out:
# 4.166666666666667

# %%
print(a*b)
# Out:
# 150

# %%
print("a+b")      (double cotes treat as string)
# Out:
# a+b
