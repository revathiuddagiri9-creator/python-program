# %% [markdown]
# <a href="https://colab.research.google.com/github/revathiuddagiri9-creator/python-program/blob/main/operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Arthematic operators
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)
print("Modulus =", a % b)
print("Floor Division =", a // b)
print("Exponentiation =", a ** b)
# Out:
# Enter first number: 20
# Enter second number: 10
# Addition = 30
# Subtraction = 10
# Multiplication = 200
# Division = 2.0
# Modulus = 0
# Floor Division = 2
# Exponentiation = 10240000000000

# %%
#Assignment operators
a = 10
print("a =", a)

a += 5
print("a += 5 =", a)

a -= 3
print("a -= 3 =", a)

a *= 2
print("a *= 2 =", a)

a /= 4
print("a /= 4 =", a)

a %= 3
print("a %= 3 =", a)

a //= 2
print("a //= 2 =", a)

a **= 2
print("a **= 2 =", a)
# Out:
# a = 10
# a += 5 = 15
# a -= 3 = 12
# a *= 2 = 24
# a /= 4 = 6.0
# a %= 3 = 0.0
# a //= 2 = 0.0
# a **= 2 = 0.0

# %%
#comparision operations
a = 10
b = 5
print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# True
# False
# True
# False

# %%
#logical operators
a = 10
b = 5
print(a > 5 and b < 10)
print(a > 15 or b < 10)
print(not(a > 5))
# Out:
# True
# True
# False

# %%
#identity operators
a = [1, 2, 3]
b = a
c = [1, 2, 3]

print(a is b)
print(a is not c)
# Out:
# True
# True

# %%
#Membership operators
a = [1, 2, 3]
b = a
c = [1, 2, 3]

print(a is b)
print(a is not c)
# Out:
# True
# True

# %%
#Bitwise operators
a = 10
b = 5

print("AND =", a & b)
print("OR =", a | b)
print("XOR =", a ^ b)
print("NOT =", ~a)
print("Left Shift =", a << 1)
print("Right Shift =", a >> 1)
# Out:
# AND = 0
# OR = 15
# XOR = 15
# NOT = -11
# Left Shift = 20
# Right Shift = 5

# %%
#Ternary operators
a = 10
b = 5
result = a if a > b else b
print("Greater number =", result)
# Out:
# Greater number = 10
